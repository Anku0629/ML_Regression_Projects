# %% [markdown]
# # LAPTOP_PRICE_ANALYSIS

# %% [markdown]
# # Introduction
#
# The Laptop Price Dataset is a comprehensive collection of data related to laptop prices, specifications, and various factors that influence the pricing of laptops. This dataset provides valuable insights into the dynamics of the laptop market, making it a valuable resource for researchers, analysts, and businesses in the technology industry.

# %% [markdown]
# # Import all the liabraries -
#
# Pandas - Used to analyse data. It has function for analysing,cleaning,exploring and manipulating data.
#
# Numpy - Mostly work on numerical values for making Arithmatic Operations.
#
# Matplotlib - Comprehensive library for creating static,animated and intractive visualization.
#
# Seaborn - Seaborn is a python data visualization library based on matplotlib. It provides a high-level interface for drawing intractive and informative statastical graphics.
#
#
#
#
#
#
#
# Warnings - warnings are provided to warn the developer of situation that are not necessarily exceptions and ignore them.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # By read_csv() function we are reading the dataset present in "laptop_train.csv" file.
#
# Took dataset on kaggle
#
# We will be making predictions models using Machine Learning Algorithams.

# %%
df=pd.read_csv("laptops_train.csv")

# %%
df
# Out:
#     Manufacturer       Model Name   Category Screen Size  \
# 0          Apple      MacBook Pro  Ultrabook       13.3"
# 1          Apple      Macbook Air  Ultrabook       13.3"
# 2             HP           250 G6   Notebook       15.6"
# 3          Apple      MacBook Pro  Ultrabook       15.4"
# 4          Apple      MacBook Pro  Ultrabook       13.3"
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming       17.3"
# 973      Toshiba  Tecra A40-C-1DF   Notebook       14.0"
# 974         Asus        Rog Strix     Gaming       17.3"
# 975           HP      Probook 450   Notebook       15.6"
# 976       Lenovo    ThinkPad T460   Notebook       14.0"
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# 2                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz   8GB
# ..                                  ...                          ...   ...
# 972                   Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  32GB
# 973                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8GB
# 974                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 975         IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8GB
# 976                            1366x768   Intel Core i5 6200U 2.3GHz   4GB
#
#                   Storage                           GPU Operating System  \
# 0               128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1     128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2               256GB SSD         Intel HD Graphics 620            No OS
# 3               512GB SSD            AMD Radeon Pro 455            macOS
# 4               256GB SSD  Intel Iris Plus Graphics 650            macOS
# ..                    ...                           ...              ...
# 972  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070          Windows
# 973             256GB SSD         Intel HD Graphics 520          Windows
# 974  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1060          Windows
# 975  128GB SSD +  1TB HDD          Nvidia GeForce 930MX          Windows
# 976          508GB Hybrid         Intel HD Graphics 520          Windows
#
#     Operating System Version  Weight        Price
# 0                        NaN  1.37kg  11912523.48
# 1                        NaN  1.34kg   7993374.48
# 2                        NaN  1.86kg   5112900.00
# 3                        NaN  1.83kg  22563005.40
# 4                        NaN  1.37kg  16037611.20
# ..                       ...     ...          ...
# 972                       10  4.42kg  24897600.00
# 973                       10  1.95kg  10492560.00
# 974                       10  2.73kg  18227710.80
# 975                       10  2.04kg   8705268.00
# 976                        7  1.70kg   8909784.00
#
# [977 rows x 13 columns]

# %% [markdown]
# # Performing Exploratory Data Analysis

# %% [markdown]
# #### Find information about data by using df.info()
#
# This laptops_train.csv dataset contains the information of patients health condition through their tests peroforms during covid19 with 977 rows and 13 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7   Storage                   977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Weight                    977 non-null    object
#  12  Price                     977 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 99.4+ KB

# %% [markdown]
# df.info() function display information about your DataFrame, including the data types of each column, the number of non-null values, and memory usage.
#
# This dataset contain 977 rows and 13 columns out of there are 1 numerical column and 12 categorical column.

# %% [markdown]
# #### To find how much null values in DataSet
#
# With the help of isnull().sum() function we got the null count of all columns.

# %%
df.isnull().sum()
# Out:
# Manufacturer                  0
# Model Name                    0
# Category                      0
# Screen Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
# Storage                       0
# GPU                           0
# Operating System              0
# Operating System Version    136
# Weight                        0
# Price                         0
# dtype: int64

# %% [markdown]
# df.isnull() method in pandas is used to check for missing or null values in a DataFrame.

# %% [markdown]
# #### Drop Unwanted Columns

# %%
df.drop("Operating System Version",axis=1,inplace=True)

# %% [markdown]
# use drop method in pandas to remove a column named "Operating System Version" from your DataFrame.

# %% [markdown]
# #### Change Datatype

# %%
df["Screen Size"] = df["Screen Size"].replace(r'[^0-9.]', '', regex=True)
df["RAM"] = df["RAM"].replace(r'[^0-9.]', '', regex=True)
df["Weight"] = df["Weight"].replace(r'[^0-9.]', '', regex=True)

# %% [markdown]
# In that removing any characters from the "Screen Size", "RAM", "Weight" column that are not digits (0-9) or a period (.). It uses a regular expression to match and replace those characters with an empty string.

# %%
df["Screen Size"]=df["Screen Size"].astype("float")
df["RAM"]=df["RAM"].astype("float")
df["Weight"]=df["Weight"].astype("float")

# %% [markdown]
# is converting the "Screen Size," "RAM," and "Weight" columns to the float data type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    float64
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    float64
#  7   Storage           977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float64
#  11  Price             977 non-null    float64
# dtypes: float64(4), object(8)
# memory usage: 91.7+ KB

# %% [markdown]
# #### Histogram

# %%
plt.figure(figsize=(10, 7))
plt.hist(df["Weight"], bins=10, edgecolor="black") 
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.title("Weight Distribution")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Pieplot

# %%
df["Category"].value_counts()
# Out:
# Notebook              549
# Ultrabook             152
# Gaming                150
# 2 in 1 Convertible     85
# Workstation            24
# Netbook                17
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(7,7))
df["Category"].value_counts().plot.pie(autopct="%1.1f%%",explode=(0,0,0,0,0,1))
plt.title("Category counts")
plt.show()

# %% [markdown]
# #### Scatterplot

# %%
df.corr()
# Out:
#              Screen Size       RAM    Weight     Price
# Screen Size     1.000000  0.232315  0.822261  0.075152
# RAM             0.232315  1.000000  0.390161  0.764005
# Weight          0.822261  0.390161  1.000000  0.224415
# Price           0.075152  0.764005  0.224415  1.000000

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x="Weight",y="Price",hue="RAM")
plt.plot()
# Out:
# []

# %% [markdown]
# #### Countplot

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df,x="Manufacturer")
plt.yticks(rotation=90)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Find Relation between each other

# %%
sns.pairplot(df)

# %% [markdown]
# The pairplot function in seaborn is a great way to quickly visualize relationships between variables.

# %% [markdown]
# #### Divide the Data into Numeric and Categorical form

# %%
num_feature=df.select_dtypes(["int64","float64"])
cat_feature=df.select_dtypes(["object"]).columns

# %% [markdown]
# Here we are saperate numerical and categorical features for perform encoding on categorical data.

# %%
num_feature
# Out:
#      Screen Size   RAM  Weight        Price
# 0           13.3   8.0    1.37  11912523.48
# 1           13.3   8.0    1.34   7993374.48
# 2           15.6   8.0    1.86   5112900.00
# 3           15.4  16.0    1.83  22563005.40
# 4           13.3   8.0    1.37  16037611.20
# ..           ...   ...     ...          ...
# 972         17.3  32.0    4.42  24897600.00
# 973         14.0   8.0    1.95  10492560.00
# 974         17.3  16.0    2.73  18227710.80
# 975         15.6   8.0    2.04   8705268.00
# 976         14.0   4.0    1.70   8909784.00
#
# [977 rows x 4 columns]

# %%
cat_feature
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen', 'CPU', 'Storage',
#        'GPU', 'Operating System'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df[cat_feature]=oe.fit_transform(df[cat_feature])

# %% [markdown]
# OrdinalEncoder is transform categorical features into numerical representations.

# %%
df
# Out:
#      Manufacturer  Model Name  Category  Screen Size  Screen   CPU   RAM  \
# 0             1.0       236.0       4.0         13.3    23.0  58.0   8.0
# 1             1.0       237.0       4.0         13.3     1.0  56.0   8.0
# 2             7.0        38.0       3.0         15.6     8.0  67.0   8.0
# 3             1.0       236.0       4.0         15.4    25.0  77.0  16.0
# 4             1.0       236.0       4.0         13.3    23.0  60.0   8.0
# ..            ...         ...       ...          ...     ...   ...   ...
# 972           4.0        43.0       1.0         17.3     8.0  83.0  32.0
# 973          16.0       339.0       3.0         14.0     8.0  61.0   8.0
# 974           2.0       318.0       1.0         17.3     8.0  93.0  16.0
# 975           7.0       293.0       3.0         15.6    15.0  68.0   8.0
# 976          10.0       362.0       3.0         14.0     0.0  61.0   4.0
#
#      Storage   GPU  Operating System  Weight        Price
# 0        2.0  51.0               6.0    1.37  11912523.48
# 1        0.0  45.0               6.0    1.34   7993374.48
# 2       15.0  47.0               4.0    1.86   5112900.00
# 3       27.0   7.0               6.0    1.83  22563005.40
# 4       15.0  52.0               6.0    1.37  16037611.20
# ..       ...   ...               ...     ...          ...
# 972     16.0  72.0               5.0    4.42  24897600.00
# 973     15.0  41.0               5.0    1.95  10492560.00
# 974     16.0  71.0               5.0    2.73  18227710.80
# 975      3.0  62.0               5.0    2.04   8705268.00
# 976     25.0  41.0               5.0    1.70   8909784.00
#
# [977 rows x 12 columns]

# %% [markdown]
# #### Splitting Data Into Features and Target

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Manufacturer  Model Name  Category  Screen Size  Screen   CPU   RAM  \
# 0             1.0       236.0       4.0         13.3    23.0  58.0   8.0
# 1             1.0       237.0       4.0         13.3     1.0  56.0   8.0
# 2             7.0        38.0       3.0         15.6     8.0  67.0   8.0
# 3             1.0       236.0       4.0         15.4    25.0  77.0  16.0
# 4             1.0       236.0       4.0         13.3    23.0  60.0   8.0
# ..            ...         ...       ...          ...     ...   ...   ...
# 972           4.0        43.0       1.0         17.3     8.0  83.0  32.0
# 973          16.0       339.0       3.0         14.0     8.0  61.0   8.0
# 974           2.0       318.0       1.0         17.3     8.0  93.0  16.0
# 975           7.0       293.0       3.0         15.6    15.0  68.0   8.0
# 976          10.0       362.0       3.0         14.0     0.0  61.0   4.0
#
#      Storage   GPU  Operating System  Weight
# 0        2.0  51.0               6.0    1.37
# 1        0.0  45.0               6.0    1.34
# 2       15.0  47.0               4.0    1.86
# 3       27.0   7.0               6.0    1.83
# 4       15.0  52.0               6.0    1.37
# ..       ...   ...               ...     ...
# 972     16.0  72.0               5.0    4.42
# 973     15.0  41.0               5.0    1.95
# 974     16.0  71.0               5.0    2.73
# 975      3.0  62.0               5.0    2.04
# 976     25.0  41.0               5.0    1.70
#
# [977 rows x 11 columns]

# %% [markdown]
# We are splitting overall data except target column that is "target" in x variable

# %%
y=df["Price"]
y
# Out:
# 0      11912523.48
# 1       7993374.48
# 2       5112900.00
# 3      22563005.40
# 4      16037611.20
#           ...
# 972    24897600.00
# 973    10492560.00
# 974    18227710.80
# 975     8705268.00
# 976     8909784.00
# Name: Price, Length: 977, dtype: float64

# %% [markdown]
# In that separate "target" column as a target in y variable.

# %% [markdown]
# #### Skewness

# %%
from scipy.stats import skew

# %% [markdown]
# Here we are calculate the skewness and visualize their distributions using sns.distplot from the Seaborn library.

# %%
from scipy.stats import skew

for i in x:
    print(i)
    print(skew(x[i]))
    
    plt.figure
    sns.distplot(x[i])
    plt.show()
# Out:
# Manufacturer
# 0.4188993369524993
# Model Name
# 0.06108869273436197
# Category
# -0.7697022136932742
# Screen Size
# -0.39686241113727416
# Screen
# 1.3478044984144508
# CPU
# -0.8706961076531857
# RAM
# 2.075028643064393
# Storage
# 0.16586773790568834
# GPU
# -0.19314119056515489
# Operating System
# -2.958763721948362
# Weight
# 1.1831011510738085

# %% [markdown]
# #### To calculate Correlation

# %%
pd.concat([x,y],axis=1).corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_74513_row0_col0, #T_74513_row1_col1, #T_74513_row2_col2, #T_74513_row3_col3, #T_74513_row4_col4, #T_74513_row5_col5, #T_74513_row6_col6, #T_74513_row7_col7, #T_74513_row8_col8, #T_74513_row9_col9, #T_74513_row10_col10, #T_74513_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_74513_row0_col1, #T_74513_row9_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_74513_row0_col2, #T_74513_row0_col6 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_74513_row0_col3, #T_74513_row5_col0, #T_74513_row5_col9, #T_74513_row7_col8 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_74513_row0_col4 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_74513_row0_col5, #T_74513_row1_col9, #T_74513_row11_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_74513_row0_col7, #T_74513_row7_col2, #T_74513_row9_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_74513_row0_col8, #T_74513_row2_col3, #T_74513_row6_col0, #T_74513_row8_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_74513_row0_col9, #T_74513_row0_col10 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_74513_row0_col11, #T_74513_row1_col8, #T_74513_row6_col1, #T_74513_row11_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_74513_row1_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_74513_row1_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_74513_row1_col3, #T_74513_row10_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_74513_row1_col4, #T_74513_row5_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_74513_row1_col5, #T_74513_row9_col8, #T_74513_row9_col10 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_74513_row1_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_74513_row1_col7, #T_74513_row3_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_74513_row1_col10, #T_74513_row2_col5, #T_74513_row2_col6, #T_74513_row2_col8, #T_74513_row2_col9, #T_74513_row2_col11, #T_74513_row3_col4, #T_74513_row3_col7, #T_74513_row4_col3, #T_74513_row10_col0, #T_74513_row10_col1, #T_74513_row10_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_74513_row1_col11, #T_74513_row11_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_74513_row2_col0, #T_74513_row5_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_74513_row2_col1, #T_74513_row8_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_74513_row2_col4, #T_74513_row8_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_74513_row2_col7, #T_74513_row3_col11 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_74513_row2_col10 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_74513_row3_col0, #T_74513_row4_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_74513_row3_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_74513_row3_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_74513_row3_col6 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_74513_row3_col8, #T_74513_row4_col5 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_74513_row3_col9 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_74513_row3_col10 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_74513_row4_col0, #T_74513_row5_col7 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_74513_row4_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_74513_row4_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_74513_row4_col6, #T_74513_row5_col10, #T_74513_row7_col6, #T_74513_row8_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_74513_row4_col7 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_74513_row4_col8, #T_74513_row9_col4, #T_74513_row11_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_74513_row4_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_74513_row4_col11 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_74513_row5_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_74513_row5_col4 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_74513_row5_col6 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_74513_row5_col8 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_74513_row5_col11 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_74513_row6_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_74513_row6_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_74513_row6_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_74513_row6_col5, #T_74513_row8_col5 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_74513_row6_col7 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_74513_row6_col8, #T_74513_row8_col10 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_74513_row6_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_74513_row6_col10 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_74513_row6_col11 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_74513_row7_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_74513_row7_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_74513_row7_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_74513_row7_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_74513_row7_col5 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_74513_row7_col9 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_74513_row7_col10, #T_74513_row10_col4 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_74513_row7_col11 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_74513_row8_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_74513_row8_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_74513_row8_col6 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_74513_row8_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_74513_row8_col11 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_74513_row9_col0, #T_74513_row9_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_74513_row9_col1, #T_74513_row9_col6 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_74513_row9_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_74513_row9_col11, #T_74513_row11_col1 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_74513_row10_col3 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_74513_row10_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_74513_row10_col6 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_74513_row10_col8 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_74513_row10_col9 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_74513_row10_col11 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_74513_row11_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_74513_row11_col5 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_74513_row11_col6 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_74513_row11_col7 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_74513_row11_col8 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_74513_row11_col10 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# </style>
# <table id="T_74513">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74513_level0_col0" class="col_heading level0 col0" >Manufacturer</th>
#       <th id="T_74513_level0_col1" class="col_heading level0 col1" >Model Name</th>
#       <th id="T_74513_level0_col2" class="col_heading level0 col2" >Category</th>
#       <th id="T_74513_level0_col3" class="col_heading level0 col3" >Screen Size</th>
#       <th id="T_74513_level0_col4" class="col_heading level0 col4" >Screen</th>
#       <th id="T_74513_level0_col5" class="col_heading level0 col5" >CPU</th>
#       <th id="T_74513_level0_col6" class="col_heading level0 col6" >RAM</th>
#       <th id="T_74513_level0_col7" class="col_heading level0 col7" >Storage</th>
#       <th id="T_74513_level0_col8" class="col_heading level0 col8" >GPU</th>
#       <th id="T_74513_level0_col9" class="col_heading level0 col9" >Operating System</th>
#       <th id="T_74513_level0_col10"

# %% [markdown]
# #### Apply Standard Scaler to Scale the data at one level

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Standardization is the process of rescaling the features so that they have the properties of a standard normal distribution with a mean of 0 and a standard deviation of 1

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# train_test_split function from scikit-learn to split your dataset into training and testing sets. This is a common in machine learning to evaluate the performance of a model.
#
# In that testing data is 20% and random state is 1.

# %%
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %% [markdown]
# We make object of standard scaler.
# In that we have to pass xtrain and xtest for transform into standard scaler.

# %%
xtrain
# Out:
# array([[-1.07903279, -0.22805363,  0.31227921, ...,  1.41651338,
#          0.31524252,  1.0089276 ],
#        [-0.59035514, -1.45062335, -1.2975562 , ...,  1.12643858,
#          0.31524252,  3.68665268],
#        [ 1.12001664, -0.71708152, -1.2975562 , ...,  0.30455997,
#          0.31524252,  3.65569632],
#        ...,
#        [ 0.87567782, -0.47997709,  0.31227921, ...,  1.56155078,
#          0.31524252,  0.86962398],
#        [-0.59035514, -0.34660584,  0.31227921, ..., -1.14581404,
#         -3.08850506,  0.49814767],
#        [-0.59035514, -0.30955828,  0.31227921, ..., -2.11273005,
#          0.31524252,  1.17918758]])

# %% [markdown]
# This is our standardize xtrain data on which we performed Standard Scaling

# %%
xtest
# Out:
# array([[ 0.16368452, -1.62605867,  0.29312381, ..., -0.74450367,
#         -0.65139055, -0.24773833],
#        [ 1.04870976, -0.96346511, -1.37215928, ...,  1.02848961,
#          0.33831912,  0.88954803],
#        [ 0.82745345,  0.75630017,  0.29312381, ..., -0.42214126,
#          0.33831912, -0.03111235],
#        ...,
#        [-0.27882811, -0.17430875,  0.29312381, ..., -0.09977884,
#          0.33831912,  0.21259187],
#        [-0.94259704,  1.61246038, -2.20480083, ..., -0.09977884,
#          0.33831912, -1.0465466 ],
#        [-0.50008442,  1.47100782,  0.29312381, ...,  0.97476254,
#          0.33831912,  0.02304414]])

# %% [markdown]
# This is our standardize xtest data on which we performed Standard Scaling

# %% [markdown]
# #### Train_Test_Split for separating data into training and testing phase

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# train_test_split function from scikit-learn to split your dataset into training and testing sets. This is a common in machine learning to evaluate the performance of a model.
#
# In that testing data is 20% and random state is 1.

# %% [markdown]
# #### Build a Model by using LinearRegression Algoritham

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %% [markdown]
# We are using the LinearRegression class from scikit-learn to fit a linear regression model in our training data (xtrain, ytrain) and make predictions on our test data (xtest).

# %% [markdown]
# #### Evaluate a model

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)
# Out:
# 0.7184981491612041

# %% [markdown]
# The r2_score function compares the predicted values (ypred) with the true values (ytest) and computes the R-squared score.

# %% [markdown]
# #### By applying Polynominal Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures()
polyx=pf.fit_transform(xtrain)

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(polyx,ytrain)
ypred_train=lr.predict(polyx)

# %%
from sklearn.metrics import r2_score
r2_score(ytrain,ypred_train)
# Out:
# 0.802676214175564

# %% [markdown]
# By using Polunominal Linear Regression we have 80% accuracy on training data.

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytrain,ypred_train)
# Out:
# 1964792.059993598

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(ytrain,ypred_train)
# Out:
# 7465365288343.721

# %%
np.sqrt(mean_squared_error(ytrain,ypred_train))
# Out:
# 2732282.066029004

# %% [markdown]
# Here we perform lost functions on training data for reduce error rate.

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures()
polyx=pf.fit_transform(xtest)

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(polyx,ytest)
ypred_test=lr.predict(polyx)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred_test)
# Out:
# 0.733590578229725

# %% [markdown]
# By using Polunominal Linear Regression we have 73% accuracy on testing data.

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,ypred_test)
# Out:
# 2727101.4497959185

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(ytest,ypred_test)
# Out:
# 12490377168834.443

# %%
np.sqrt(mean_squared_error(ytest,ypred_test))
# Out:
# 3534172.7700884184

# %% [markdown]
# Here we perform lost functions on testing data for reduce error rate.

# %% [markdown]
# #### Support Vector Regression

# %%
from sklearn.svm import SVR

# Create an SVR model
svr = SVR(kernel='rbf', C=1.0, epsilon=0.1)

# Train the model
svr.fit(xtrain, ytrain)

# Make predictions
ypred_test = svr.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.7184981491612041

# %% [markdown]
# Here we evaluate the performance of our SVR model using appropriate regression metrics such as R2_score.
